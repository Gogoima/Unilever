# %% [markdown]
# ## Description of files:
#
# V.id: Unique vehicle id
#
# On road old: On road price of the vehicle when purchased from showroom in rupees
#
# New on road: new on road price in rupees
#
# Years: Vehicles age
#
# km: total distance covered by vehicle in km
#
# Rating: Overall rating of the new vehicle out of 5
#
# Condition: current condition of the vehicle out of 10(note :- higher the number better the condition is)
#
# Economy: current fuel economy of the vehicle per liter.
#
# Top speed: current top speed of the vehicle indicated by dyno test.
#
# Hp: horse power of the engine indicated by dyno test.
#
# Torque: torque of the engine indicated by dyno test.
#
# Current price: predicted price of the vehicle .

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train_data = pd.read_csv("UNI.csv")

# %%
train_data.head(5)
# Out:
#    v.id  on road old  on road now  years     km   rating  condition  economy  \
# 0     1       535651       798186      3   78945       1          2       14
# 1     2       591911       861056      6  117220       5          9        9
# 2     3       686990       770762      2  132538       2          8       15
# 3     4       573999       722381      4  101065       4          3       11
# 4     5       691388       811335      6   61559       3          9       12
#
#    top speed  hp  torque  current price
# 0        177  73     123       351318.0
# 1        148  74      95       285001.5
# 2        181  53      97       215386.0
# 3        197  54     116       244295.5
# 4        160  53     105       531114.5

# %%
#Checking for any null values throughout the dataframe.
train_data.isnull().values.any()
# Out:
# False

# %%
train_data.describe()
# Out:
#               v.id    on road old  on road now        years            km   \
# count  1000.000000    1000.000000    1000.0000  1000.000000    1000.000000
# mean    500.500000  601648.286000  799131.3970     4.561000  100274.430000
# std     288.819436   58407.246204   57028.9502     1.719079   29150.463233
# min       1.000000  500265.000000  700018.0000     2.000000   50324.000000
# 25%     250.750000  548860.500000  750997.7500     3.000000   74367.500000
# 50%     500.500000  601568.000000  798168.0000     5.000000  100139.500000
# 75%     750.250000  652267.250000  847563.2500     6.000000  125048.000000
# max    1000.000000  699859.000000  899797.0000     7.000000  149902.000000
#
#             rating    condition      economy   top speed          hp  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.00000
# mean      2.988000     5.592000    11.625000   166.89300    84.54600
# std       1.402791     2.824449     2.230549    19.28838    20.51694
# ...

# %%
### Univariate distribution plot
import matplotlib.pyplot as plt
for col in train_data.columns:
    hist = sns.distplot(train_data[col], bins=1000)
    print("Plotting for column {}".format(col))
    plt.show()
# Out:
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Plotting for column v.id
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Plotting for column on road old
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Plotting for column on road now
# ...

# %%
### Bivariate plot
for col in train_data.columns:
    hist = sns.jointplot(train_data['current price'],train_data[col],size =10)
    print("Plotting for column current price and {}".format(col))
    plt.show()
# Out:
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# Plotting for column current price and v.id
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /Users/manuranjangogoi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# ...

# %%
train_data.corr()
# Out:
#                    v.id  on road old  on road now     years       km   \
# v.id           1.000000    -0.029926    -0.030787 -0.034255  0.047400
# on road old   -0.029926     1.000000     0.034113  0.007207  0.007488
# on road now   -0.030787     0.034113     1.000000  0.004609 -0.053202
# years         -0.034255     0.007207     0.004609  1.000000 -0.002089
# km             0.047400     0.007488    -0.053202 -0.002089  1.000000
# rating        -0.018263    -0.050717     0.028280  0.027285 -0.039930
# condition     -0.038548    -0.015682    -0.005043  0.053579 -0.013640
# economy        0.047137    -0.030097    -0.015880  0.050220  0.032680
# top speed      0.001613    -0.023816     0.012699  0.025148  0.026450
# hp            -0.006997    -0.049266    -0.012719 -0.003272 -0.052918
# torque        -0.000632     0.008950     0.017955  0.028859  0.013566
# current price -0.059460     0.233035     0.282793 -0.011854 -0.935924
#
# ...

# %%
df= np.array(train_data)

# %%
df[np.tril_indices_from(df)] = False
sns.heatmap(train_data, mask=df,vmax=.8, square=True,annot=True)
